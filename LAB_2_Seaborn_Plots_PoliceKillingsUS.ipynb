# %% [markdown]
# <a href="https://colab.research.google.com/github/denizbaris/Data_Visualization_Python/blob/main/LAB_2_Seaborn_Plots_PoliceKillingsUS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill.shape
# Out:
# (2535, 14)

# %%
kill.dropna(inplace=True)

# %%
kill.shape
# Out:
# (2254, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(x = "gender", y = "age" , data = kill, hue="manner_of_death")
plt.show()

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn
fig, ax = plt.subplots(figsize=(8,6))
sns.swarmplot(x = "gender" , y = "age", data=kill, hue="manner_of_death");

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
dcity = kill.city.value_counts()[:12]
dcity
# Out:
# Los Angeles     35
# Phoenix         28
# Houston         24
# Chicago         22
# Austin          18
# Las Vegas       17
# Columbus        16
# Miami           15
# San Antonio     15
# Indianapolis    14
# St. Louis       14
# Bakersfield     13
# Name: city, dtype: int64

# %%
# with seaborn barplot
fig, ax = plt.subplots(figsize=(8,6))
sns.barplot(x = dcity.index, y = dcity.values)
ax.set_xticklabels(dcity.index, rotation = 45)
ax.set_title("Most Dangerous City", color= "b", fontsize=12);

# %%
# with seaborn countplot
fig, ax = plt.subplots(figsize=(10,6))
sns.countplot(x = "city", data = kill, order = dcity.index)
ax.set_xticklabels(dcity.index, rotation =45)
ax.set_title("Most Dangereous City", color = "b", fontsize=12)
plt.show()

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
dstate = kill.state.value_counts()[:20]
dstate
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# IL     56
# TN     56
# WA     51
# LA     47
# PA     45
# AL     45
# NY     43
# VA     43
# WI     42
# SC     41
# Name: state, dtype: int64

# %%
# with seaborn barplot
fig, ax = plt.subplots(figsize=(8,6))
sns.barplot(x=dstate.index, y=dstate.values)
ax.set_xticklabels(dstate.index,rotation=45)
ax.set_title("Most Dangerous States", color="b", fontsize=12);

# %%
# with seaborn countplot
fig, ax = plt.subplots(figsize=(8,6))
sns.countplot(x = "state", data = kill, order=dstate.index)
ax.set_xticklabels(dstate.index, rotation =45)
ax.set_title("Most Dangereous States", color = "b", fontsize=14);

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
mental_illness = kill.signs_of_mental_illness.value_counts()
mental_illness
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
# with seaborn
sns.countplot(kill.signs_of_mental_illness);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threat_type = kill.threat_level.value_counts()
threat_type
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
# with seaborn
sns.countplot(kill.threat_level);

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_types = kill.flee.value_counts()
flee_types
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
# with seaborn
sns.countplot(kill.flee);
